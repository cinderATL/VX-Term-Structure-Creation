# %%
import pandas as pd


pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows', None)

import requests
from bs4 import BeautifulSoup

import os
from os import listdir

# %%
os.getcwd()
# Out:
# 'C:\\Users\\cinderella\\dataSci\\DataScience\\eliteDataScience\\07-CapstoneProject\\Final\\_projectNotebooks'

# %%
os.chdir('C:\\Users\\cinderella\\dataSci\\DataScience\\eliteDataScience\\07-CapstoneProject\\Final\\Data-RAW-VX\\VX2018')
#os.getcwd()

# %% [markdown]
# ## Before even getting to cleaning up the data...
# Open your directory on your computer to Final/Data-RAW-VX and take a look at the file sizes. I would expect the sizes to be from 11 to 14K. Early year files may be incomplete (for the free version), so maybe they won't be as large. The future future year (2021) is underway, but just barely, so some of these won't be as large as full contract files. <br>
# But take a look at M18, there is no reason this should be so scant, same with subsequent months within that contract year. Since we took these from the Far Past, maybe the data in the Not So Far Past would be better. <br><br>
# Make sure you have a folder within the Data-RAW-VX directory called VX2018, this is where these new downloads will go. If they are not put inside of their own folder, they will eat the old files you already downloaded. (We are **pretending** I don't know if these files will be better..but this is good practice anyway)

# %% [markdown]
# ## Download the recent historical data.. Calendar year 2018

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-01-17"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_F18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-02-14"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_G18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-03-21"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_H18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-04-18"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_J18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-05-16"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_K18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-06-20"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_M18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-07-18"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_N18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-08-22"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_Q18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-09-19"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_U18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-10-17"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_V18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-11-21"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_X18_VX.csv")

# %%
url = "https://markets.cboe.com/us/futures/market_statistics/historical_data/products/csv/VX/2018-12-19"
data = pd.read_csv(url)
data.head
data.to_csv("CFE_Z18_VX.csv")

# %% [markdown]
# ### Do we dare check?

# %%
dfM18 = pd.read_csv('CFE_M18_VX.csv')
dfM18
# Out:
#      Unnamed: 0  Trade Date       Futures   Open   High    Low  Close  Settle  \
# 0             0  2017-09-25  M (Jun 2018)   0.00  16.95  17.40   0.00  17.175
# 1             1  2017-09-26  M (Jun 2018)  17.00  17.00  16.90  16.95  17.000
# 2             2  2017-09-27  M (Jun 2018)  16.90  17.05  16.90  17.04  17.025
# 3             3  2017-09-28  M (Jun 2018)  17.00  17.05  16.99  17.00  17.000
# 4             4  2017-09-29  M (Jun 2018)  17.00  17.05  16.95  16.95  16.975
# 5             5  2017-10-02  M (Jun 2018)  16.95  16.95  16.77  16.85  16.775
# 6             6  2017-10-03  M (Jun 2018)  16.76  16.82  16.63  16.70  16.700
# 7             7  2017-10-04  M (Jun 2018)  16.70  16.70  16.67  16.70  16.675
# 8             8  2017-10-05  M (Jun 2018)  16.65  16.65  16.50  16.50  16.500
# 9             9  2017-10-06  M (Jun 2018)  16.60  16.60  16.55  16.55  16.550
# 10           10  2017-10-09  M (Jun 2018)  16.55  16.70  16.55  16.70  16.700
# ...

# %% [markdown]
# #### Equal parts Yeah and Boo, but a plus for actual data we can use.
# Notice in your directory that all of these files are similar in size. Now physically copy these files into your directory named Data-RAW-VX. They will eat over the 2018 files we were not sure of. Yes, these have an extra index.. more on that later.

# %%
os.chdir('C:\\Users\\cinderella\\dataSci\\DataScience\\eliteDataScience\\07-CapstoneProject\\Final\\')
